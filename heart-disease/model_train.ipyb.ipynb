# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('heart.csv')

# %% [markdown]
# Changing sex to is_male

# %%
data['Sex'] = data['Sex'].apply(lambda x: 1 if x == 'male' else 0)
data.rename(columns={'Sex':'is_male'},inplace=True)

# %%
data['ChestPainType'].value_counts()
# Out:
# ChestPainType
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: count, dtype: int64

# %%
data = pd.get_dummies(data,columns=['ChestPainType'])

# %%
data['ChestPainType_ASY'] = data['ChestPainType_ASY'].astype(int)
data['ChestPainType_ATA'] = data['ChestPainType_ATA'].astype(int)
data['ChestPainType_NAP'] = data['ChestPainType_NAP'].astype(int)
data['ChestPainType_TA'] = data['ChestPainType_TA'].astype(int)
# Out:
#      Age  is_male  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0     40        0        140          289          0     Normal    172
# 1     49        0        160          180          0     Normal    156
# 2     37        0        130          283          0         ST     98
# 3     48        0        138          214          0     Normal    108
# 4     54        0        150          195          0     Normal    122
# ..   ...      ...        ...          ...        ...        ...    ...
# 913   45        0        110          264          0     Normal    132
# 914   68        0        144          193          1     Normal    141
# 915   57        0        130          131          0     Normal    115
# 916   57        0        130          236          0        LVH    174
# 917   38        0        138          175          0     Normal    173
#
#     ExerciseAngina  Oldpeak ST_Slope  HeartDisease  ChestPainType_ASY  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['RestingECG'] = le.fit_transform(data['RestingECG'])

# %%
data['ExerciseAngina'] = data['ExerciseAngina'].apply(lambda x: 0 if x == 'N' else 1)

# %%
data['ST_Slope'] = data['ST_Slope'].apply(lambda x: 0 if x == 'Flat' else(1 if x == 'Up' else -1))

# %%
x = data.drop('HeartDisease', axis=1)
y = data['HeartDisease']

# %%
ros = RandomOverSampler(random_state=42)
x_resampled, y_resampled = ros.fit_resample(x, y)

# %%
data = x_resampled.join(y_resampled)

# %%
x = data.drop('HeartDisease', axis=1)
y = data['HeartDisease']

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc_model = RandomForestClassifier()
rfc_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rfc_model.score(x_test,y_test)
# Out:
# 0.8578431372549019

# %%
from sklearn.linear_model import LogisticRegression
lr_model = LogisticRegression()
lr_model.fit(x_train,y_train)
# Out:
# c:\Users\SubodhG\Documents\heart-disease\venv\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr_model.score(x_test,y_test)
# Out:
# 0.8529411764705882

# %%
from sklearn.svm import SVC
svc_model = SVC()
svc_model.fit(x_train,y_train)
svc_model.score(x_test,y_test)
# Out:
# 0.696078431372549

# %%
import pickle

# Save the RandomForestClassifier model to a file
with open('rfc_model.pkl', 'wb') as file:
    pickle.dump(rfc_model, file)
